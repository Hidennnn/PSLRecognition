# %%
import time
from tensorflow.keras.models import load_model
from preprocessing import vector_of_points, distance
from utils import rescale_image
import joblib
import cv2
import numpy as np
from PIL import ImageFont

# %%
scaler = joblib.load("scaler_arrays.save")
model = load_model("best_model2.h5")

# %%
labels = {}
file_labels = open(r"C:\Users\PC\OneDrive\Pulpit\projekty\psl\text\labels.txt", "r")
count = 0
for line in file_labels:
    labels[count] = line[:-1]
    count += 1

file_labels.close()

# %%
labels[21] = "ty"
labels[22] = "on/ona"

# %%
import cv2
time.sleep(3)
cv2.namedWindow("preview")
vc = cv2.VideoCapture(0)
font = ImageFont.truetype(r"C:\Users\PC\Downloads\arial\arial.ttf", 80)
text = ""

while True:
    start = time.time()
    rval, frame = vc.read()
    frame = cv2.rotate(frame, cv2.ROTATE_90_CLOCKWISE)
    vector = vector_film(frame)
    frame = rescale_frame(frame, 50)
    try:
        distance = distance_more_complex(vector)
        distance = scaler.transform([distance])
        predict = model.predict(distance)
        index = np.where(predict == np.amax(predict))[1][0]
        text = labels[index]
        cv2.putText(frame, text, org = (200, 900), fontFace = cv2.FONT_HERSHEY_SIMPLEX, fontScale = 4, color = (255, 255, 255), thickness = 6, lineType = cv2.LINE_AA)
        cv2.putText(frame, text, org = (200, 900), fontFace = cv2.FONT_HERSHEY_SIMPLEX, fontScale = 4, color = (0, 0, 0), thickness = 4, lineType = cv2.LINE_AA)

    except:
        a = 0


    cv2.putText(frame, text, org = (100, 900), fontFace = cv2.FONT_HERSHEY_SIMPLEX, fontScale = 4, color = (255, 255, 255), thickness = 6, lineType = cv2.LINE_AA)
    cv2.putText(frame, text, org = (100, 900), fontFace = cv2.FONT_HERSHEY_SIMPLEX, fontScale = 4, color = (0, 0, 0), thickness = 4, lineType = cv2.LINE_AA)
    print(frame.shape)
    cv2.imshow("preview", frame)
    cv2.waitKey(1)

vc.release()
cv2.destroyWindow("preview")
# Out:
# 1/1 [==============================] - 0s 15ms/step
# [[1.0870522e-22 8.5751518e-22 1.0206517e-33 0.0000000e+00 7.2507609e-29
#   1.1222113e-34 8.9934776e-21 2.3931560e-28 6.0734628e-29 6.5176713e-27
#   1.1435713e-21 1.0000000e+00 1.9414208e-18 1.1735955e-23 1.6337460e-22
#   2.4063803e-31 8.6264659e-22 2.9082417e-19 3.8903559e-24 5.7480515e-27
#   1.9644430e-23 1.0813477e-24 7.8453334e-27 2.7815788e-21 1.1118094e-20
#   5.8476330e-30 3.1224882e-22]]

# %%
cv2.destroyWindow("preview")

# %%
# Python program to save a
# video using OpenCV


import cv2


# Create an object to read
# from camera
video = cv2.VideoCapture(0)

# We need to check if camera
# is opened previously or not
if (video.isOpened() == False):
    print("Error reading video file")

# We need to set resolutions.
# so, convert them from float to integer.
frame_width = int(video.get(3))
frame_height = int(video.get(4))

size = (int(0.5*frame_height), int(0.5*frame_width))

# Below VideoWriter object will create
# a frame of above defined The output
# is stored in 'filename.avi' file.
result = cv2.VideoWriter('filename.avi',
                         cv2.VideoWriter_fourcc(*'MJPG'),
                         10, size)

font = ImageFont.truetype(r"C:\Users\PC\Downloads\arial\arial.ttf", 80)
text = ""

time.sleep(3)

czas = time.time()

while(True):
    ret, frame = video.read()


    frame = cv2.rotate(frame, cv2.ROTATE_90_CLOCKWISE)
    vector = vector_of_points(frame)
    print(vector)
    frame = rescale_image(frame, 50)
    try:
        dist = distance(vector)
        dist = scaler.transform([dist])
        predict = model.predict(dist)
        index = np.where(predict == np.amax(predict))[1][0]
        text = labels[index]

    except:
        print("HAHAHAHHAHAHAHAHHA")

    cv2.putText(frame, text, org = (100, 900), fontFace = cv2.FONT_HERSHEY_SIMPLEX, fontScale = 4, color = (255, 255, 255), thickness = 6, lineType = cv2.LINE_AA)
    cv2.putText(frame, text, org = (100, 900), fontFace = cv2.FONT_HERSHEY_SIMPLEX, fontScale = 4, color = (0, 0, 0), thickness = 4, lineType = cv2.LINE_AA)
    result.write(frame)
    cv2.imshow('Frame', frame)

        # Press S on keyboard
        # to stop the process
    print(czas - time.time())
    if time.time() - czas >= 30:
        break
    cv2.waitKey(1)

# write objects
video.release()
result.release()

# Closes all the frames
cv2.destroyAllWindows()

print("The video was successfully saved")
# Out:
# Holistic doesn't detect pose.
# None
# HAHAHAHHAHAHAHAHHA
# -0.3722963333129883
# ...

# %%
cv2.destroyAllWindows()
